# %%
import pandas as pd

sales = pd.read_csv('Walmart_Sales.csv')
# print(sales.loc[0:20])
# print(sales.head())
# print(sales.info())
# print(sales.shape)
# print(sales.describe())
# print(sales.values)
# print(sales.columns)
# print(sales.index)
# Out:
# RangeIndex(start=0, stop=6435, step=1)

# %%
sales.sort_values(['Weekly_Sales', 'Unemployment'], ascending=[False, True])
# Out:
#       Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 1905     14  24-12-2010    3818686.45             0        30.59       3.141
# 2763     20  24-12-2010    3766687.43             0        25.17       3.141
# 1333     10  24-12-2010    3749057.69             0        57.06       3.236
# 527       4  23-12-2011    3676388.98             0        35.92       3.103
# 1762     13  24-12-2010    3595903.20             0        34.90       2.846
# ...     ...         ...           ...           ...          ...         ...
# 4671     33  02-12-2011     220060.35             0        59.12       3.701
# 4623     33  31-12-2010     219804.85             1        52.91       3.148
# 4675     33  30-12-2011     215359.21             1        51.60       3.428
# 4614     33  29-10-2010     213538.32             0        71.34       3.130
# 4619     33  03-12-2010     209986.25             0        52.82       3.041
#
#              CPI  Unemployment
# ...

# %%
sales['Temperature'].sum()
# Out:
# np.float64(390371.44)

# %%
def pct75(column):
    return column.quantile(0.75)

def pct25(column):
    return column.quantile(0.25)

# sales[['Temperature', 'Weekly_Sales']].agg([pct75, pct25])

def iqr(column):
    return column.quantile(0.75) - column.quantile(0.25)

sales[['Temperature', 'Weekly_Sales']].agg(iqr)
# Out:
# Temperature         27.480
# Weekly_Sales    866808.555
# dtype: float64

# %%
# sales.groupby(['Store', 'Holiday_Flag'])[['Weekly_Sales', 'Fuel_Price']].agg(['min', 'max', 'sum'])
# sales.groupby('Store')['Weekly_Sales'].agg('mean')
# Out:
# Store
# 1     1.555264e+06
# 2     1.925751e+06
# 3     4.027044e+05
# 4     2.094713e+06
# 5     3.180118e+05
# 6     1.564728e+06
# 7     5.706173e+05
# 8     9.087495e+05
# 9     5.439806e+05
# 10    1.899425e+06
# 11    1.356383e+06
# 12    1.009002e+06
# 13    2.003620e+06
# 14    2.020978e+06
# 15    6.233125e+05
# 16    5.192477e+05
# 17    8.935814e+05
# 18    1.084718e+06
# 19    1.444999e+06
# 20    2.107677e+06
# 21    7.560691e+05
# 22    1.028501e+06
# 23    1.389864e+06
# 24    1.356755e+06
# 25    7.067215e+05
# 26    1.002912e+06
# 27    1.775216e+06
# 28    1.323522e+06
# 29    5.394514e+05
# 30    4.385796e+05
# 31    1.395901e+06
# 32    1.166568e+06
# 33    2.598617e+05
# 34    9.667816e+05
# 35    9.197250e+05
# 36    3.735120e+05
# 37    5.189003e+05
# 38    3.857317e+05
# 39    1.450668e+06
# 40    9.641280e+05
# 41    1.268125e+06
# 42    5.564039e+05
# 43    6.333247e+05
# 44    3.027489e+05
# 45    7.859814e+05
# Name: Weekly_Sales, dtype: float64

# %%
sales.pivot_table(values='Weekly_Sales', index='Store', aggfunc=['median', 'mean'], columns='Holiday_Flag', margins=True)
# Out:
#                   median                                   mean                \
# Holiday_Flag           0            1         All             0             1
# Store
# 1             1530761.43  1645786.185  1534849.64  1.546957e+06  1.665748e+06
# 2             1876788.15  2001049.875  1879107.31  1.914209e+06  2.079267e+06
# 3              394918.83   415641.420   395107.35  4.000648e+05  4.378110e+05
# 4             2065377.15  2156476.005  2073951.38  2.083556e+06  2.243103e+06
# 5              309111.47   335175.050   310338.17  3.148923e+05  3.595016e+05
# 6             1524059.40  1602182.190  1524390.07  1.555993e+06  1.680908e+06
# 7              553714.87   605505.890   557166.35  5.629645e+05  6.724003e+05
# 8              892393.77   963480.885   893399.77  9.037434e+05  9.753309e+05
# 9              535153.47   553978.250   536537.64  5.405993e+05  5.889508e+05
# 10            1826241.44  2023049.340  1827521.71  1.883309e+06  2.113756e+06
# ...
